# %%
import numpy as np
import pandas as pd
import csv

# %%
# Loading dataset.
babies_data = pd.read_csv("babynames/yob2010.txt")
babies_data
# Out:
#         Isabella  F  22731
# 0         Sophia  F  20477
# 1           Emma  F  17179
# 2         Olivia  F  16860
# 3            Ava  F  15300
# 4          Emily  F  14172
# ...          ... ..    ...
# 33832    Zymaire  M      5
# 33833     Zyonne  M      5
# 33834  Zyquarius  M      5
# 33835      Zyran  M      5
# 33836      Zzyzx  M      5
#
# [33837 rows x 3 columns]

# %%
babies_data.head(20)
# Out:
#      Isabella  F  22731
# 0      Sophia  F  20477
# 1        Emma  F  17179
# 2      Olivia  F  16860
# 3         Ava  F  15300
# 4       Emily  F  14172
# 5     Abigail  F  14124
# 6     Madison  F  13070
# 7       Chloe  F  11656
# 8         Mia  F  10541
# 9     Addison  F  10253
# 10  Elizabeth  F  10135
# 11       Ella  F   9796
# 12    Natalie  F   8715
# 13   Samantha  F   8334
# 14     Alexis  F   8181
# 15       Lily  F   7900
# 16      Grace  F   7598
# 17     Hailey  F   6969
# 18     Alyssa  F   6934
# 19    Lillian  F   6898

# %%
babies_data[1:10]
# Out:
#   Isabella  F  22731
# 1     Emma  F  17179
# 2   Olivia  F  16860
# 3      Ava  F  15300
# 4    Emily  F  14172
# 5  Abigail  F  14124
# 6  Madison  F  13070
# 7    Chloe  F  11656
# 8      Mia  F  10541
# 9  Addison  F  10253

# %%
babies_data.iloc[1:15]
# Out:
#      Isabella  F  22731
# 1        Emma  F  17179
# 2      Olivia  F  16860
# 3         Ava  F  15300
# 4       Emily  F  14172
# 5     Abigail  F  14124
# 6     Madison  F  13070
# 7       Chloe  F  11656
# 8         Mia  F  10541
# 9     Addison  F  10253
# 10  Elizabeth  F  10135
# 11       Ella  F   9796
# 12    Natalie  F   8715
# 13   Samantha  F   8334
# 14     Alexis  F   8181

# %%
babies_data.loc["Aryana"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Aryana'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-b5e3f664138f> in <module>
# ----> 1 babies_data.loc["Aryana"]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
# ...

# %%
babies_data.loc[17179]

# %%
babies_data.columns = ["Name", "Gender", "DoB"]
babies_data.tail(5)
# Out:
#             Name Gender  DoB
# 33832    Zymaire      M    5
# 33833     Zyonne      M    5
# 33834  Zyquarius      M    5
# 33835      Zyran      M    5
# 33836      Zzyzx      M    5

# %%
babies_data.columns
# Out:
# Index(['Name', 'Gender', 'DoB'], dtype='object')

# %%
babies_data
# Out:
#             Name Gender    DoB
# 0         Sophia      F  20477
# 1           Emma      F  17179
# 2         Olivia      F  16860
# 3            Ava      F  15300
# 4          Emily      F  14172
# ...          ...    ...    ...
# 33832    Zymaire      M      5
# 33833     Zyonne      M      5
# 33834  Zyquarius      M      5
# 33835      Zyran      M      5
# 33836      Zzyzx      M      5
#
# [33837 rows x 3 columns]

# %%
babies_data['age']=np.arange(1,len(babies_data)+1)
babies_data.tail(5)
# Out:
#             Name Gender  DoB    age
# 33832    Zymaire      M    5  33833
# 33833     Zyonne      M    5  33834
# 33834  Zyquarius      M    5  33835
# 33835      Zyran      M    5  33836
# 33836      Zzyzx      M    5  33837

# %%
babies_data[babies_data == "Zymaire"].tail(5)
# Out:
#           Name Gender  DoB  age
# 33832  Zymaire    NaN  NaN  NaN
# 33833      NaN    NaN  NaN  NaN
# 33834      NaN    NaN  NaN  NaN
# 33835      NaN    NaN  NaN  NaN
# 33836      NaN    NaN  NaN  NaN

# %%
age = 33835
babies_data[babies_data["age"] > age].tail(5)
# Out:
#         Name Gender  DoB    age
# 33835  Zyran      M    5  33836
# 33836  Zzyzx      M    5  33837
