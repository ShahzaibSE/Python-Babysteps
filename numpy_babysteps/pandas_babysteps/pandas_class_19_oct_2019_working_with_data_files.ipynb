# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("./data-files/data.csv")
data
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
data.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
data.loc[0]
# Out:
# Student Code            022-14-19987
# Degree                        BS(CS)
# Student Name             Abdul Basit
# Mid                               28
# Quiz 1                             8
# Quiz 2                             3
# Best of Quizzes                    8
# Assignment 1                       7
# Assignment 2                       9
# Best of Assignments                9
# Total Sessional (50)              45
# Final (50)                        25
# Total (100)                       70
# Grade                              B
# Name: 0, dtype: object

# %%
data.head(1)
# Out:
#    Student Code  Degree Student Name  Mid  Quiz 1  Quiz 2  Best of Quizzes  \
# 0  022-14-19987  BS(CS)  Abdul Basit   28     8.0     3.0                8
#
#    Assignment 1  Assignment 2  Best of Assignments  Total Sessional (50)  \
# 0           7.0           9.0                    9                    45
#
#    Final (50)  Total (100) Grade
# 0        25.0           70     B

# %%
data.iloc[1:4]
# Out:
#     Student Code  Degree    Student Name  Mid  Quiz 1  Quiz 2  \
# 1  022-14-110233  BS(CS)     Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)    Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)  Ahmed Ali Raza   14     7.0     2.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 1                    32        18.0           50     F
# 2                    33        30.0           63     C
# 3                    23        23.0           46     F

# %%
data.iloc[0]
# Out:
# Student Code            022-14-19987
# Degree                        BS(CS)
# Student Name             Abdul Basit
# Mid                               28
# Quiz 1                             8
# Quiz 2                             3
# Best of Quizzes                    8
# Assignment 1                       7
# Assignment 2                       9
# Best of Assignments                9
# Total Sessional (50)              45
# Final (50)                        25
# Total (100)                       70
# Grade                              B
# Name: 0, dtype: object

# %%
data.iloc[1:3]
# Out:
#     Student Code  Degree  Student Name  Mid  Quiz 1  Quiz 2  Best of Quizzes  \
# 1  022-14-110233  BS(CS)   Adeel Ahmed   17     NaN     5.0                5
# 2  022-14-110585  BS(CS)  Afrah Zareen   18     5.0     2.0                5
#
#    Assignment 1  Assignment 2  Best of Assignments  Total Sessional (50)  \
# 1           8.0          10.0                   10                    32
# 2           8.0          10.0                   10                    33
#
#    Final (50)  Total (100) Grade
# 1        18.0           50     F
# 2        30.0           63     C

# %%
data[data["Assignment 1"] >= 7]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# ...

# %%
# pd.options.display.max_rows = 5
# data

# %%
data
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
data[data["Assignment 1"] >= 8]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# ...

# %%
len(data[data["Assignment 1"] >= 8])
# Out:
# 32

# %%
data[data["Assignment 1"] >= 8].count()
# Out:
# Student Code            32
# Degree                  32
# Student Name            32
# Mid                     32
# Quiz 1                  30
# Quiz 2                  31
# Best of Quizzes         32
# Assignment 1            32
# Assignment 2            24
# Best of Assignments     32
# Total Sessional (50)    32
# Final (50)              32
# Total (100)             32
# Grade                   32
# dtype: int64

# %%
data[data["Assignment 2"] >= 8]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 14  022-14-110389  BS(CS)                   Hareem Afshan   21     7.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# ...

# %%
data[data["Assignment 2"] >= 8].count()
# Out:
# Student Code            33
# Degree                  33
# Student Name            33
# Mid                     33
# Quiz 1                  31
# Quiz 2                  31
# Best of Quizzes         33
# Assignment 1            32
# Assignment 2            33
# Best of Assignments     33
# Total Sessional (50)    33
# Final (50)              33
# Total (100)             33
# Grade                   33
# dtype: int64

# %%
data[(data["Assignment 2"] >= 7) & (data["Assignment 2"] == 8)]
# Out:
#      Student Code  Degree             Student Name  Mid  Quiz 1  Quiz 2  \
# 14  022-14-110389  BS(CS)            Hareem Afshan   21     7.0     4.0
# 26  022-14-110370  BS(CS)  Muhammad Ghazali Faridi   27     6.0     NaN
# 43  022-14-110451  BS(CS)        Syed Faizan Uddin   28     9.0     4.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 14                7           6.0           8.0                    8
# 26                6           6.0           8.0                    8
# 43                9           6.0           8.0                    8
#
#     Total Sessional (50)  Final (50)  Total (100) Grade
# 14                    36        29.0           65     C
# 26                    41        24.0           65     C
# 43                    45        34.0           79     B

# %%
data[(data["Assignment 1"] >= 7) | (data["Assignment 2"] == 10)]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
data[(data["Assignment 2"] >= 7) & (data["Assignment 2"] == 8)]["Student Name"]
# Out:
# 14              Hareem Afshan
# 26    Muhammad Ghazali Faridi
# 43          Syed Faizan Uddin
# Name: Student Name, dtype: object

# %%
"Muhammad Abdullah".startswith("Muhammad")
# Out:
# True

# %%
print(data["Student Name"].index.name)
# Out:
# None

# %%
data[(data["Student Name"].str.startswith("Muhammad")) | (data["Student Name"].str.startswith("Mohammad"))]["Student Name"]
# Out:
# 19                   Mohammad Hunain
# 20                    Muhammad Aamir
# 21    Muhammad Abdul Rehman Siddiqui
# 22                 Muhammad Abdullah
# 23                Muhammad Ali Iqbal
# 24                    Muhammad Bilal
# 25                    Muhammad Faraz
# 26           Muhammad Ghazali Faridi
# 27               Muhammad Osama Khan
# 28            Muhammad Saqib Intizar
# 29         Muhammad Shahroz Khurshid
# 30                   Muhammad Shozab
# 31             Muhammad Taha Hasnain
# 32             Muhammad Wajahat Khan
# 33              Muhammad Younus Baig
# Name: Student Name, dtype: object

# %%
data["Student Name"].str.split(" ")
# Out:
# 0                          [Abdul, Basit]
# 1                          [Adeel, Ahmed]
# 2                         [Afrah, Zareen]
# 3                      [Ahmed, Ali, Raza]
# 4                     [Ahsan, Ali, Vohra]
# 5                          [Ameer, Hamza]
# 6                       [Anas, Ali, Khan]
# 7                     [Aneebullah, Niazi]
# 8                       [Areesha, Sohail]
# 9                               [Arsalan]
# 10                [Fatima, Haider, Warsi]
# 11                         [Habib, Ullah]
# 12                [Hafiza, Tooba, Akbani]
# 13                 [Hamza, Abdul, Jabbar]
# 14                       [Hareem, Afshan]
# 15                        [Haseeb, Sajid]
# 16                        [Hassam, Ahmed]
# 17                        [Khalid, Anwer]
# 18                       [Madiha, Jabeen]
# 19                     [Mohammad, Hunain]
# 20                      [Muhammad, Aamir]
# 21    [Muhammad, Abdul, Rehman, Siddiqui]
# ...

# %%
data[data["Student Name"] == "Abdul Basit"]
# Out:
#    Student Code  Degree Student Name  Mid  Quiz 1  Quiz 2  Best of Quizzes  \
# 0  022-14-19987  BS(CS)  Abdul Basit   28     8.0     3.0                8
#
#    Assignment 1  Assignment 2  Best of Assignments  Total Sessional (50)  \
# 0           7.0           9.0                    9                    45
#
#    Final (50)  Total (100) Grade
# 0        25.0           70     B

# %% [markdown]
# ## Sorting and Ranking

# %%
obj = pd.Series(range(4), index=['d', 'a', 'b', 'c'])
obj
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
# Now with Dataframe.
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),index=['three', 'one'],columns=['d', 'a', 'b', 'c'])
frame
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index()
# Out:
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3

# %%
frame.sort_index(ascending=False)
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index(axis=1,ascending=False)
# Out:
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5

# %%
frame
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
data
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
data.sort_values(by=["Mid", "Best of Quizzes", "Assignment 2"]) # Precedence of First column is high.
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 47  022-14-110219  BS(CS)                     Waqar Ahmed   11     9.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 29  022-14-110217  BS(CS)       Muhammad Shahroz Khurshid   17     7.0
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 41  022-14-110225  BS(CS)                   Shariqa Ahmad   20     7.0
# ...

# %%
obj2 = pd.Series([4, 7, -3, 2])
obj2
# Out:
# 0    4
# 1    7
# 2   -3
# 3    2
# dtype: int64

# %%
obj2.sort_values()
# Out:
# 2   -3
# 3    2
# 0    4
# 1    7
# dtype: int64

# %%
obj2.sort_values(kind="bubble")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-220-3aa80c6829cb> in <module>()
# ----> 1 obj.sort_values(kind="bubble")
#
# /Users/shahzaibnoor/anaconda/lib/python3.5/site-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    1708         idx = _default_index(len(self))
#    1709
# -> 1710         argsorted = _try_kind_sort(arr[good])
#    1711
#    1712         if is_list_like(ascending):
#
# /Users/shahzaibnoor/anaconda/lib/python3.5/site-packages/pandas/core/series.py in _try_kind_sort(arr)
#    1694             try:
#    1695                 # if kind==mergesort, it can fail for object dtype
# -> 1696                 return arr.argsort(kind=kind)
#    1697             except TypeError:
#    1698                 # stable sort not available for object dtype
#
# ValueError: bubble is an unrecognized kind of sort

# %%
obj2

# %% [markdown]
# ## Ranking

# %%
obj = pd.Series([7, 2, 1, -10])
obj
# Out:
# 0     7
# 1     2
# 2     1
# 3   -10
# dtype: int64

# %%
obj.rank()
# Out:
# 0    4.0
# 1    3.0
# 2    2.0
# 3    1.0
# dtype: float64

# %%
obj.sum()
# Out:
# 0

# %%
df = pd.DataFrame([[1.4, 2.2], [7.1, 4.5], [12,11], [0.75, 1.3]],index=['a', 'b', 'c', 'd'],columns=['one', 'two'])
df
# Out:
#      one   two
# a   1.40   2.2
# b   7.10   4.5
# c  12.00  11.0
# d   0.75   1.3

# %%
df.cumsum()
# Out:
#      one   two
# a   1.40   2.2
# b   8.50   6.7
# c  20.50  17.7
# d  21.25  19.0

# %%
# Checking values in columns of csv data.
data[data["Assignment 2"].isin([8,10])]
# Out:
#      Student Code  Degree             Student Name  Mid  Quiz 1  Quiz 2  \
# 1   022-14-110233  BS(CS)              Adeel Ahmed   17     NaN     5.0
# 2   022-14-110585  BS(CS)             Afrah Zareen   18     5.0     2.0
# 5   022-14-110232  BS(CS)              Ameer Hamza   25     9.0     6.0
# 6   022-14-110588  BS(CS)            Anas Ali Khan   28     5.0     6.0
# 7   022-14-110388  BS(CS)         Aneebullah Niazi   26     9.0     6.0
# 12  022-15-110994  BS(CS)      Hafiza Tooba Akbani   23     7.0     5.0
# 13  022-14-110600  BS(CS)       Hamza Abdul Jabbar   24     8.0     4.0
# 14  022-14-110389  BS(CS)            Hareem Afshan   21     7.0     4.0
# 18  022-14-110223  BS(CS)            Madiha Jabeen   16     5.0     2.0
# 19  022-14-110222  BS(CS)          Mohammad Hunain   27     9.0     6.0
# 23   022-14-19983  BS(CS)       Muhammad Ali Iqbal   26     5.0     NaN
# 25  022-14-110105  BS(CS)           Muhammad Faraz   26     9.0     6.0
# ...

# %%
data = pd.read_csv("./data-files/data.csv", header=None)
data
# Out:
#                                                                                                                                                                  one  \
# Student Code  Degree Student Name                   Mid Quiz 1 Quiz 2 Best of Quizzes Assignment 1 Assignment 2 Best of Assignments Total Sessional (50)  Final (50)
# 022-14-19987  BS(CS) Abdul Basit                    28  8      3      8               7            9            9                   45                            25
# 022-14-110233 BS(CS) Adeel Ahmed                    17  NaN    5      5               8            10           10                  32                            18
# 022-14-110585 BS(CS) Afrah Zareen                   18  5      2      5               8            10           10                  33                            30
# ...
